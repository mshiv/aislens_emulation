# %%
import xarray as xr
import numpy as np
from sklearn.datasets import load_breast_cancer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
inDirName = '/Users/smurugan9/Library/R/arm64/4.1/library/fldgen/extdata/tann1.nc'

# %%
data = xr.open_dataset(inDirName)

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:    (lon: 288, bnds: 2, lat: 192, time: 95)
# Coordinates:
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#     height     float64 ...
#   * time       (time) object 2006-07-01 06:00:00 ... 2100-07-01 06:00:00
# Dimensions without coordinates: bnds
# Data variables:
#     lon_bnds   (lon, bnds) float64 ...
#     lat_bnds   (lat, bnds) float64 ...
#     time_bnds  (time, bnds) object ...
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/38)
#     CDI:                          Climate Data Interface version 1.8.2 (http:...
#     Conventions:                  CF-1.4
#     history:                      Wed Oct 18 11:59:51 2017: cdo yearmonmean /...
#     source:                       CESM1-CAM5
#     institution:                  NSF/DOE NCAR (National Center for Atmospher...
#     institute_id:                 NSF-DOE-NCAR
# ...

# %%
data.tas.std('time').plot()

# %%
data.tas
# Out:
# <xarray.DataArray 'tas' (time: 95, lat: 192, lon: 288)>
# array([[[223.88132, 224.07114, ..., 223.89923, 224.08904],
#         [224.33571, 224.44484, ..., 224.50984, 224.53278],
#         ...,
#         [253.83884, 253.84756, ..., 253.82005, 253.82967],
#         [253.71822, 253.71892, ..., 253.7166 , 253.71745]],
#
#        [[224.58951, 224.7818 , ..., 224.609  , 224.80247],
#         [224.89677, 225.00565, ..., 225.11356, 225.13234],
#         ...,
#         [253.96959, 253.9851 , ..., 253.93721, 253.95364],
#         [253.92455, 253.92548, ..., 253.92242, 253.92354]],
#
#        ...,
#
#        [[227.62482, 227.75087, ..., 227.64442, 227.76097],
#         [228.10808, 228.137  , ..., 228.23795, 228.24886],
#         ...,
#         [261.2898 , 261.29312, ..., 261.28275, 261.28635],
#         [261.30014, 261.3001 , ..., 261.30026, 261.3002 ]],
#
#        [[226.58432, 226.70479, ..., 226.60292, 226.71513],
#         [227.20694, 227.23615, ..., 227.3433 , 227.35432],
#         ...,
# ...
